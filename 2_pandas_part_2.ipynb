# %% [markdown]
# Step 1 → How does the data look?        → head()
# Step 2 → How big is the data?           → shape
# Step 3 → What columns exist?            → info()
# Step 4 → Any numbers to summarize?      → describe()
# Step 5 → Any missing values?            → isnull()
# ## This is called EDA
